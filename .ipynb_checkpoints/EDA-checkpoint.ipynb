# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_1 = pd.read_csv(f'/Users/pasindumalinda/Folder_01/exploratory_data_analysis/Zomatodataset/zomato.csv', encoding = 'latin-1')
data_v1 = data_1.copy()

# %%
data_v1.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
data_v1.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
data_v1.shape
# Out:
# (9551, 21)

# %%
data_v1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
data_v1.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %% [markdown]
# # In data Analysis what all things we do
#
# * Missing values
# * Explore about the numerical variables
# * Explore About categorical variables
# * Finding relationship between features

# %% [markdown]
# ### Check the missing values use difference ways

# %%
# one way to find a missing vlaues

data_v1.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
# Another way to find missing values

for features in data_v1.columns:
    missing_count = data_v1[features].isnull().sum()

    if missing_count > 0:
        print(f'{features}: {missing_count}')
# Out:
# Cuisines: 9

# %%
# Although this method can use to find a missing values
plt.figure(figsize = (13,6))
sns.heatmap(
    data_v1.isnull(),
    yticklabels = False,
    cbar = False,
    cmap = 'viridis'
)
# Out:
# <Axes: >

# %%
# Calculate missing values per column
missing_values = data_v1.isnull().sum()

# Plot the missing values
plt.figure(figsize=(8, 7))
missing_values[missing_values > 0].plot(kind='bar', color='#1124F2')
plt.title('Missing Values per Column', fontsize=16)
plt.xlabel('Columns', fontsize=14)
plt.ylabel('Number of Missing Values', fontsize=14)
plt.show()

# %%
data_2 = pd.read_excel(f'/Users/pasindumalinda/Folder_01/exploratory_data_analysis/Zomatodataset/Country-Code.xlsx')
data_v2 = data_2.copy()

# %%
data_v2.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
# Meging this table and main dataset together

data_3 = pd.merge(left = data_v1, right = data_v2,
                 on = 'Country Code',
                 how = 'left')
data_v3 = data_3.copy()

# %%
data_v3.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
data_v3.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# Country                  object
# dtype: object

# %%
data_v3.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
data_v3['Country'].value_counts()
# Out:
# Country
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# UAE                 60
# South Africa        60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Singapore           20
# Qatar               20
# Sri Lanka           20
# Canada               4
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create the count plot
plt.figure(figsize=(12, 6))  # Adjust the figure size for better readability
ax = sns.countplot(
    y='Country',             # Use 'y' for horizontal bars, 'x' for vertical bars
    data=data_v3,             # Specify the DataFrame
    order=data_v3['Country'].value_counts().index,  # Order by frequency
    hue = 'Country'
)

# Add labels and title
plt.title('Count of Countries', fontsize=16)
plt.xlabel('Count', fontsize=14)
plt.ylabel('Country', fontsize=14)

# Annotate the count on top of each bar
for p in ax.patches:
    width = p.get_width()  # Get the width of the bar (which represents the count)
    plt.text(
        width + 0.1,       # x-position: slightly to the right of the bar
        p.get_y() + p.get_height() / 2,  # y-position: middle of the bar
        f'{int(width)}',   # Text to display (the count)
        ha='left',         # Horizontal alignment
        va='center'        # Vertical alignment
    )

# Show the plot
plt.show()

# %%
country_names = data_v3.value_counts().index
country_val = data_v3.value_counts().values

# %%
import matplotlib.pyplot as plt

# Get the top 5 countries
top_5_countries = data_v3['Country'].value_counts().nlargest(3)

# Create labels and sizes for the pie chart
labels = top_5_countries.index  # Country names
sizes = top_5_countries.values  # Counts
explode = (0.1, 0, 0)  # "Explode" the first slice for emphasis

# Create the pie chart
plt.figure(figsize=(10, 10))  # Set the size of the chart
patches, texts, autotexts = plt.pie(
    sizes,                   # Sizes of the pie slices
    labels=labels,           # Labels for each slice
    autopct='%1.2f%%',       # Display percentages with 1 decimal place
    startangle=45,           # Rotate the chart for better readability
    explode=explode,         # Explode the first slice
    shadow=True,             # Add a shadow effect
    colors=plt.cm.Pastel1.colors,  # Use a pastel color scheme
    textprops={'fontsize': 12}  # Set font size for labels and percentages
)

# Adjust the position of percentage values and labels
for text in texts + autotexts:
    text.set_fontsize(12)  # Set font size for better readability

# Add a title
plt.title('Top 5 Countries by Count', fontsize=16, pad=20)

# Add a legend
plt.legend(
    title='Country',         # Legend title
    loc='upper right',       # Position of the legend
    bbox_to_anchor=(1.3, 1), # Adjust legend position outside the chart
    fontsize=12              # Set font size for legend
)

# Show the chart
plt.tight_layout()  # Ensure everything fits in the figure
plt.show()

# %% [markdown]
# ## Observation:Zomato maximum records or transaction are from India After that USA and then United Kingdoms

# %%
data_v3.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
# Check the rating 

ratings = data_v3.groupby(by = ['Aggregate rating', 'Rating color', 'Rating text']).size().reset_index().rename(columns = {0: 'Rating Count'})

# %%
ratings
# Out:
#     Aggregate rating Rating color Rating text  Rating Count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# ...

# %% [markdown]
# # Observation
# 1. When Rating is between 4.5 to 4.9 > Excellent
# 2. When Rating are between 4.0 to 3.4-->very good
# 3. when Rating is between 3.5 to 3.9-> good
# 4. when Rating is between 3.0 to 3.4--> average
# 5. when Rating is between 2.5 to 2.9 > average
# 6. when Rating is between 2.0 to 2.4 > Poor

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Define a color mapping for the 'Rating color' column
color_mapping = {
    'White': 'black',
    'Red': 'red',
    'Orange': 'orange',
    'Yellow': 'yellow',
    'Green': 'green',
    'Dark Green': 'darkgreen'
}

# Map the 'Rating color' column to valid color codes
ratings['Color Code'] = ratings['Rating color'].map(color_mapping)

# Create the bar plot
plt.figure(figsize=(17, 8))
ax = sns.barplot(
    x='Aggregate rating',  # X-axis: Aggregate rating
    y='Rating Count',      # Y-axis: Rating Count
    data=ratings,          # Data source
    hue='Rating color',    # Hue: Rating color
    palette=color_mapping, # Use the color mapping dictionary
    dodge=False            # Ensure bars are not dodged (grouped)
)

# Add count annotations on top of each bar
for p in ax.patches:
    ax.annotate(
        f'{int(p.get_height())}',  # Text to display (count)
        (p.get_x() + p.get_width() / 2., p.get_height()),  # Position of the annotation
        ha='center',               # Horizontal alignment
        va='bottom',               # Vertical alignment
        fontsize=12,               # Font size
        color='black',             # Text color
        xytext=(0, 5),             # Offset for text position
        textcoords='offset points'
    )

# Customize the plot
plt.title('Aggregate Rating Count with Rating Colors', fontsize=16)
plt.xlabel('Aggregate Rating', fontsize=14)
plt.ylabel('Rating Count', fontsize=14)
plt.legend(title='Rating Color', bbox_to_anchor=(1.05, 1), loc='upper left')  # Move legend outside

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Observation
# 1. Not Rated count is very high
# 2. Maximum number of rating rate between 2.6 to 4.3

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create the count plot
plt.figure(figsize=(10, 6))
ax = sns.countplot(
    y='Rating color',  # Use 'y' for horizontal bars, 'x' for vertical bars
    data=ratings,      # Data source
    order=ratings['Rating color'].value_counts().index,  # Order by frequency
    hue='Rating color',  # Assign 'Rating color' to hue
    palette=color_mapping,  # Use the color mapping dictionary
    legend=False  # Disable the legend (since y-axis already shows the colors)
)

# Add count annotations on top of each bar
for p in ax.patches:
    ax.annotate(
        f'{int(p.get_width())}',  # Text to display (count)
        (p.get_width() + 0.1, p.get_y() + p.get_height() / 2),  # Position of the annotation
        ha='left',               # Horizontal alignment
        va='center',             # Vertical alignment
        fontsize=12,             # Font size
        color='black'            # Text color
    )

# Customize the plot
plt.title('Count of Rating Colors', fontsize=16)
plt.xlabel('Count', fontsize=14)
plt.ylabel('Rating Color', fontsize=14)

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Which cantries are have Zero rating 

zero_rating_data = data_v3[data_v3['Aggregate rating'] == 0]
country_names = zero_rating_data.groupby('Country').size().reset_index(name = 'Zero rating count')
country_names
# Out:
#           Country  Zero rating count
# 0          Brazil                  5
# 1           India               2139
# 2  United Kingdom                  1
# 3   United States                  3

# %% [markdown]
# * Observation Maximum number of 0 Rating are from Indian customer

# %%
data_v3.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
# find out which currency is used by which country?

currency_by_country = data_v3[['Country', 'Currency']].drop_duplicates().reset_index(drop = True)
currency_by_country
# Out:
#            Country                Currency
# 0      Phillipines        Botswana Pula(P)
# 1           Brazil      Brazilian Real(R$)
# 2    United States               Dollar($)
# 3        Australia               Dollar($)
# 4           Canada               Dollar($)
# 5        Singapore               Dollar($)
# 6              UAE      Emirati Diram(AED)
# 7            India      Indian Rupees(Rs.)
# 8        Indonesia  Indonesian Rupiah(IDR)
# 9      New Zealand           NewZealand($)
# 10  United Kingdom              Pounds(£)
# 11           Qatar         Qatari Rial(QR)
# 12    South Africa                 Rand(R)
# 13       Sri Lanka   Sri Lankan Rupee(LKR)
# 14          Turkey        Turkish Lira(TL)

# %%
# Find out the online delivary  available countries 

online_delivery_by_country = data_v3.groupby('Country')['Has Online delivery'].apply(lambda x:
                                                                                    'Yes' if 'Yes' in x.values else 'No').reset_index()
online_delivery_by_country
# Out:
#            Country Has Online delivery
# 0        Australia                  No
# 1           Brazil                  No
# 2           Canada                  No
# 3            India                 Yes
# 4        Indonesia                  No
# 5      New Zealand                  No
# 6      Phillipines                  No
# 7            Qatar                  No
# 8        Singapore                  No
# 9     South Africa                  No
# 10       Sri Lanka                  No
# 11          Turkey                  No
# 12             UAE                 Yes
# 13  United Kingdom                  No
# 14   United States                  No

# %% [markdown]
# ## Observation:
# * Online Delivaries are available in India and USE

# %%
data_v3.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Assuming your data is stored in a DataFrame called `data_v3`
# Count the number of occurrences of each city
city_distribution = data_v3['City'].value_counts()

# Get the top 4 cities
top_4_cities = city_distribution.head(5)

# Set a professional color palette using seaborn
colors = sns.color_palette('pastel')[0:5]  # Use a pastel color palette

# Create a pie chart with a professional look
plt.figure(figsize=(10, 8))  # Set the size of the pie chart

# Plot the pie chart
wedges, texts, autotexts = plt.pie(
    top_4_cities,
    autopct='%1.1f%%',
    startangle=45,
    colors=colors,
    shadow=True,
    labels=top_4_cities.index,
    explode=(0.05, 0.05, 0.05, 0.05, 0.05),  # Slightly separate the slices
    textprops={'fontsize': 12, 'fontweight': 'bold'}  # Customize percentage text
)

# Add a legend outside the graph
plt.legend(
    wedges,
    top_4_cities.index,
    title="Cities",
    loc="upper left",  # Position of the legend
    bbox_to_anchor=(1, 1),  # Move the legend outside the graph (right side)
    fontsize=12
)

# Add a title
plt.title('Top 4 Cities Distribution', fontsize=16, fontweight='bold', pad=20)

# Add a white circle in the center to make it look like a donut chart (optional)
centre_circle = plt.Circle((0, 0), 0.70, fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

# Equal aspect ratio ensures that the pie is drawn as a circle
plt.axis('equal')

# Display the pie chart
plt.tight_layout()  # Adjust layout to prevent overlap
plt.show()

# %%
# Assuming your data is stored in a DataFrame called `data_v3`
# Count the number of occurrences of each city
Top_Cuisines = data_v3['Cuisines'].value_counts()

# Get the top 4 cities
top_5_Cuisines = Top_Cuisines.head(5)

# Set a professional color palette using seaborn
colors = sns.color_palette('pastel')[0:5]  # Use a pastel color palette

# Create a pie chart with a professional look
plt.figure(figsize=(10, 8))  # Set the size of the pie chart

# Plot the pie chart
wedges, texts, autotexts = plt.pie(
    top_5_Cuisines,
    autopct='%1.1f%%',
    startangle=45,
    colors=colors,
    shadow=True,
    labels=top_5_Cuisines.index,
    explode=(0.05, 0.05, 0.05, 0.05, 0.05),  # Slightly separate the slices
    textprops={'fontsize': 12, 'fontweight': 'bold'}  # Customize percentage text
)

# Add a legend outside the graph
plt.legend(
    wedges,
    top_4_cities.index,
    title='Cuisines',
    loc="upper left",  # Position of the legend
    bbox_to_anchor=(1, 1),  # Move the legend outside the graph (right side)
    fontsize=12
)

# Add a title
plt.title('Top 5 Cuisines', fontsize=16, fontweight='bold', pad=20)

# Add a white circle in the center to make it look like a donut chart (optional)
centre_circle = plt.Circle((0, 0), 0.70, fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

# Equal aspect ratio ensures that the pie is drawn as a circle
plt.axis('equal')

# Display the pie chart
plt.tight_layout()  # Adjust layout to prevent overlap
plt.show()
